# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# data  = pd.read_csv("Desktop/Projects/AgriYield_AI/datasets/weather_data.csv")
# df = pd.DataFrame(data)

# %%
# df
# Out:
#       Rainfall  Temperature  Humidity  Month  Year          Region
# 0          3.5         22.3      72.9      1  1997  Andhra Pradesh
# 1          2.2         24.9      66.1      2  1997  Andhra Pradesh
# 2          1.8         30.8      62.7      3  1997  Andhra Pradesh
# 3          4.1         32.9      59.2      4  1997  Andhra Pradesh
# 4          3.1         34.9      67.6      5  1997  Andhra Pradesh
# ...        ...          ...       ...    ...   ...             ...
# 8635      73.2         26.8      74.8      8  2020     West Bengal
# 8636      53.8         26.5      74.7      9  2020     West Bengal
# 8637       3.7         24.8      71.6     10  2020     West Bengal
# 8638       1.6         21.3      75.9     11  2020     West Bengal
# 8639       0.3         20.8      73.4     12  2020     West Bengal
#
# [8640 rows x 6 columns]

# %%
# df.shape
# Out:
# (8640, 6)

# %%
# df.columns
# Out:
# Index(['Rainfall', 'Temperature', 'Humidity', 'Month', 'Year', 'Region'], dtype='object')

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rainfall     8640 non-null   float64
#  1   Temperature  8640 non-null   float64
#  2   Humidity     8640 non-null   float64
#  3   Month        8640 non-null   int64
#  4   Year         8640 non-null   int64
#  5   Region       8640 non-null   object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 405.1+ KB

# %%
# df.isnull().sum()
# Out:
# Rainfall       0
# Temperature    0
# Humidity       0
# Month          0
# Year           0
# Region         0
# dtype: int64

# %%
# df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# print("Number of regions:", df["Region"].nunique())
# print("\nRegions:")
# print(df["Region"].unique())
# Out:
# Number of regions: 30
#
# Regions:
# ['Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh'
#  'Delhi' 'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir'
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab' 'Sikkim'
#  'Tamil Nadu' 'Telangana' 'Tripura' 'Uttar Pradesh' 'Uttarakhand'
#  'West Bengal']

# %%
# df["Region"].value_counts()
# Out:
# Region
# Andhra Pradesh       288
# Arunachal Pradesh    288
# Assam                288
# Bihar                288
# Chhattisgarh         288
# Delhi                288
# Goa                  288
# Gujarat              288
# Haryana              288
# Himachal Pradesh     288
# Jammu and Kashmir    288
# Jharkhand            288
# Karnataka            288
# Kerala               288
# Madhya Pradesh       288
# Maharashtra          288
# Manipur              288
# Meghalaya            288
# Mizoram              288
# Nagaland             288
# Odisha               288
# Puducherry           288
# Punjab               288
# Sikkim               288
# Tamil Nadu           288
# Telangana            288
# Tripura              288
# Uttar Pradesh        288
# Uttarakhand          288
# West Bengal          288
# Name: count, dtype: int64

# %%
# weather_cols = [
#     "Rainfall",
#     "Temperature",
#     "Humidity"
# ]

# %%
# df[weather_cols].describe().T
# Out:
#               count       mean        std   min   25%   50%   75%    max
# Rainfall     8640.0  26.508333  50.735876   0.0   1.7   4.8  28.9  843.7
# Temperature  8640.0  23.751308   7.083265  -2.5  19.3  24.9  28.5   39.6
# Humidity     8640.0  68.835104  10.990963  39.3  59.9  68.4  78.1   98.0

# %%
# df[weather_cols].median()
# Out:
# Rainfall        4.8
# Temperature    24.9
# Humidity       68.4
# dtype: float64

# %%
# df[weather_cols].median()
# Out:
# Rainfall        4.8
# Temperature    24.9
# Humidity       68.4
# dtype: float64

# %%
# plt.figure(figsize=(8, 5))

# sns.histplot(data=df, x="Rainfall", kde=True)

# plt.title("Distribution of Rainfall")
# plt.xlabel("Rainfall")
# plt.ylabel("Frequency")
# plt.show()

# %%
# plt.figure(figsize=(8, 5))

# sns.histplot(data=df, x="Temperature", kde=True)

# plt.title("Distribution of Temperature")
# plt.xlabel("Temperature")
# plt.ylabel("Frequency")
# plt.show()

# %%
# plt.figure(figsize=(8, 5))

# sns.histplot(data=df, x="Humidity", kde=True)

# plt.title("Distribution of Humidity")
# plt.xlabel("Humidity")
# plt.ylabel("Frequency")
# plt.show()

# %%
# monthly_weather = (
#     df.groupby("Month")[["Rainfall", "Temperature", "Humidity"]]
#     .mean()
# )

# monthly_weather
# Out:
#         Rainfall  Temperature   Humidity
# Month
# 1       3.735556    15.955000  71.819167
# 2       3.656389    19.070694  70.254583
# 3       3.571528    26.332917  66.589861
# 4       3.605694    31.141389  64.368889
# 5       3.756667    31.845000  63.825000
# 6      64.170694    28.665000  67.963750
# 7      93.128750    25.445139  70.556806
# 8      79.673056    24.621250  70.419722
# 9      51.852778    23.947500  69.547361
# 10      3.657500    22.286528  68.792778
# 11      3.741111    19.050972  70.405694
# 12      3.550278    16.654306  71.477639

# %%
# plt.figure(figsize=(10, 5))

# sns.lineplot(
#     data=monthly_weather,
#     x=monthly_weather.index,
#     y="Rainfall",
#     marker="o"
# )

# plt.title("Average Monthly Rainfall")
# plt.xlabel("Month")
# plt.ylabel("Average Rainfall")
# plt.xticks(range(1, 13))

# plt.show()

# %%
# plt.figure(figsize=(10, 5))

# sns.lineplot(
#     data=monthly_weather,
#     x=monthly_weather.index,
#     y="Temperature",
#     marker="o"
# )

# plt.title("Average Monthly Temperature")
# plt.xlabel("Month")
# plt.ylabel("Average Temperature")
# plt.xticks(range(1, 13))

# plt.show()

# %%
# plt.figure(figsize=(10, 5))

# sns.lineplot(
#     data=monthly_weather,
#     x=monthly_weather.index,
#     y="Humidity",
#     marker="o"
# )

# plt.title("Average Monthly Humidity")
# plt.xlabel("Month")
# plt.ylabel("Average Humidity")
# plt.xticks(range(1, 13))

# plt.show()

# %%
# yearly_weather = (
#     df.groupby("Year")[["Rainfall", "Temperature", "Humidity"]]
#     .mean()
# )

# yearly_weather
# Out:
#        Rainfall  Temperature   Humidity
# Year
# 1997  26.030000    23.656111  68.700556
# 1998  26.608889    23.585556  68.713611
# 1999  25.224722    23.617778  68.695556
# 2000  26.773056    23.644167  68.797222
# 2001  30.302222    23.756944  69.119167
# 2002  25.865000    23.591944  68.643889
# 2003  22.931111    23.826667  68.676111
# 2004  28.705556    23.822500  68.774444
# 2005  24.395556    23.676111  68.598333
# 2006  26.659444    23.629444  69.305000
# 2007  27.144167    23.816111  68.874167
# 2008  28.718611    23.724444  68.868611
# 2009  29.038889    23.904722  69.099444
# 2010  25.396111    23.778611  68.577500
# 2011  25.070833    23.690833  69.093333
# 2012  27.577500    23.713611  69.058333
# 2013  27.200833    23.830000  68.839722
# 2014  27.119444    23.744444  68.875000
# 2015  23.057778    23.860278  68.662500
# 2016  28.563056    23.785556  68.871389
# 2017  24.109722    23.958889  68.632500
# 2018  28.792500    23.867500  68.886667
# ...

# %%
# plt.figure(figsize=(12, 5))

# sns.lineplot(
#     data=yearly_weather,
#     x=yearly_weather.index,
#     y="Rainfall"
# )

# plt.title("Average Annual Rainfall Trend")
# plt.xlabel("Year")
# plt.ylabel("Average Rainfall")

# plt.show()

# %%
# plt.figure(figsize=(12, 5))

# sns.lineplot(
#     data=yearly_weather,
#     x=yearly_weather.index,
#     y="Temperature"
# )

# plt.title("Average Annual Temperature Trend")
# plt.xlabel("Year")
# plt.ylabel("Average Temperature")

# plt.show()

# %%
# plt.figure(figsize=(12, 5))

# sns.lineplot(
#     data=yearly_weather,
#     x=yearly_weather.index,
#     y="Humidity"
# )

# plt.title("Average Annual Humidity Trend")
# plt.xlabel("Year")
# plt.ylabel("Average Humidity")

# plt.show()

# %%
# region_weather = (
#     df.groupby("Region")[["Rainfall", "Temperature", "Humidity"]]
#     .mean()
#     .sort_values("Rainfall", ascending=False)
# )

# region_weather
# Out:
#                     Rainfall  Temperature   Humidity
# Region
# Goa                57.993750    27.248264  79.957292
# Meghalaya          47.783681    20.088889  86.434375
# Kerala             46.561111    27.103472  83.628125
# Assam              35.741319    23.944097  81.607639
# Sikkim             35.520139    13.991667  81.305903
# West Bengal        34.840972    26.040278  77.571181
# Tripura            33.811806    24.166667  81.245139
# Arunachal Pradesh  33.734722    18.061111  79.461111
# Mizoram            31.368056    21.101736  79.203472
# Nagaland           29.902778    21.031944  77.063889
# Uttarakhand        28.016319    17.952431  66.237153
# Odisha             26.063194    27.190625  71.198611
# Bihar              25.952431    26.032986  69.141667
# Chhattisgarh       24.610764    27.099653  63.267708
# Andhra Pradesh     24.307292    28.136806  66.057292
# Manipur            24.121528    20.044792  76.939583
# Uttar Pradesh      23.713542    24.787500  60.984028
# ...

# %%
# plt.figure(figsize=(12, 8))

# sns.barplot(
#     data=df,
#     x="Rainfall",
#     y="Region",
#     estimator="mean",
#     errorbar=None
# )

# plt.title("Average Rainfall by Region")
# plt.xlabel("Average Rainfall")
# plt.ylabel("Region")

# plt.show()

# %%
# plt.figure(figsize=(12, 8))

# sns.barplot(
#     data=df,
#     x="Temperature",
#     y="Region",
#     estimator="mean",
#     errorbar=None
# )

# plt.title("Average Temperature by Region")
# plt.xlabel("Average Temperature")
# plt.ylabel("Region")

# plt.show()

# %%
# plt.figure(figsize=(12, 8))

# sns.barplot(
#     data=df,
#     x="Humidity",
#     y="Region",
#     estimator="mean",
#     errorbar=None
# )

# plt.title("Average Humidity by Region")
# plt.xlabel("Average Humidity")
# plt.ylabel("Region")

# plt.show()

# %%
# weather_corr = df[weather_cols].corr()

# weather_corr
# Out:
#              Rainfall  Temperature  Humidity
# Rainfall     1.000000     0.100735  0.290875
# Temperature  0.100735     1.000000 -0.255652
# Humidity     0.290875    -0.255652  1.000000

# %%
# plt.figure(figsize=(8, 6))

# sns.heatmap(
#     weather_corr,
#     annot=True,
#     fmt=".2f"
# )

# plt.title("Correlation Between Weather Variables")
# plt.show()

# %%
# sns.pairplot(
#     df[weather_cols]
# )

# plt.show()

# %%
# #Outlier Analysis
# for col in weather_cols:
#     plt.figure(figsize=(8, 4))

#     sns.boxplot(x=df[col])

#     plt.title(f"Boxplot of {col}")
#     plt.xlabel(col)

#     plt.show()

# %%
# for col in weather_cols:

#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)

#     IQR = Q3 - Q1

#     lower = Q1 - 1.5 * IQR
#     upper = Q3 + 1.5 * IQR

#     outliers = df[
#         (df[col] < lower) |
#         (df[col] > upper)
#     ]

#     print(f"{col}")
#     print("Lower bound:", lower)
#     print("Upper bound:", upper)
#     print("Outliers:", len(outliers))
#     print()
# Out:
# Rainfall
# Lower bound: -39.099999999999994
# Upper bound: 69.69999999999999
# Outliers: 1075
#
# Temperature
# Lower bound: 5.500000000000002
# Upper bound: 42.3
# Outliers: 142
#
# Humidity
# Lower bound: 32.60000000000001
# Upper bound: 105.39999999999999
# Outliers: 0

# %%
# print("Rainfall < 0:", (df["Rainfall"] < 0).sum())
# print("Temperature < 0:", (df["Temperature"] < 0).sum())
# print("Humidity < 0:", (df["Humidity"] < 0).sum())
# print("Humidity > 100:", (df["Humidity"] > 100).sum())
# Out:
# Rainfall < 0: 0
# Temperature < 0: 31
# Humidity < 0: 0
# Humidity > 100: 0

# %%
# print("Invalid months:", (~df["Month"].between(1, 12)).sum())
# Out:
# Invalid months: 0

# %%
# print("Years:", df["Year"].min(), "to", df["Year"].max())
# Out:
# Years: 1997 to 2020

# %%
# ## Weather Dataset EDA Conclusions

# - The weather dataset contains 8,640 observations and 6 attributes.
# - The dataset contains rainfall, temperature, humidity, month, year,
#   and region information.
# - No missing values were identified.
# - No duplicate records were identified.
# - The distributions of rainfall, temperature, and humidity were examined
#   to understand their variation and potential skewness.
# - Monthly analysis was performed to identify seasonal weather patterns.
# - Yearly analysis was performed to identify long-term weather trends.
# - Region-wise analysis was performed to compare weather conditions across
#   different regions.
# - Correlation analysis was performed to examine relationships between
#   rainfall, temperature, and humidity.
# - Outlier analysis was performed on the major weather variables.
# - Physical and logical validity checks were performed for rainfall,
#   temperature, humidity, month, and year.
# - The Region, Year, and Month attributes are particularly important for
#   integrating weather information with agricultural records.
# - Further analysis will be performed after integrating the weather data
#   with crop/yield and soil datasets.
